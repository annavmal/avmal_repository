# %% [markdown]
# Домашнее задание к лекции "Функции"
# Вам нужно помочь секретарю автоматизировать работу. Для этого нужно написать программу, которая будет на основе хранимых данных исполнять пользовательские команды.
#
# Исходные данные имеют следующую структуру:
#
# перечень всех документов
# documents = [
#  {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
#  {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
#  {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
# ]
# перечень полок, на которых хранятся документы (если документ есть в documents, то он обязательно должен быть и в directories)
# directories = {
#  '1': ['2207 876234', '11-2'],
#  '2': ['10006'],
#  '3': []
# }
# Общие требования к программе:
#
# код должен быть грамотно декомпозирован (каждая функция отвечает за свою конкретную задачу, дублирующийся функционал переиспользуется, а его код не повторяется);
# в коде отсутствуют глобальные переменные (за исключением documents и directories);
# пользовательский ввод обрабатывается в цикле while до тех пор, пока пользователь явно не завершит программу (вводом команды "q").

# %% [markdown]
# пользовательский ввод обрабатывается в цикле while до тех пор, пока пользователь явно не завершит программу (вводом команды “q”).
#
# Задание 1
# Пункт 1. Пользователь по команде “p” может узнать владельца документа по его номеру
# Пункт 2. Пользователь по команде “s” может по номеру документа узнать на какой полке он хранится
# Пункт 3. Пользователь по команде “l” может увидеть полную информацию по всем документам
# Пункт 4. Пользователь по команде “as” может добавить новую полку

# %%
def main_func():
    while True: 
        user_input = input('Введите команду:')
        if user_input == 'p':
            print(name_by_doc())
        elif user_input == 's':
            print(shelf_by_doc())
        elif user_input == 'l':
            print(all_docs())
        elif user_input == 'ads':
            print(add_new_shelf())
        elif user_input == 'q':    
            print('До свидания')
            break
main_func()
# Out:
# Введите команду:s
# Введите номер документа:10006
# Результат: Документ хранится на полке: 2
# Введите команду:q
# До свидания

# %%
#перечень всех документов
documents = [
 {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
 {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
 {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
# перечень полок, на которых хранятся документы (если документ есть в documents, то он обязательно должен быть и в directories)
directories = {
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': []
}

# %% [markdown]
# Задание 1 Пункт 1. Пользователь по команде "p" может узнать владельца документа по его номеру Примеры работы:
#
# 1.
#
# Введите команду: p
#
# Введите номер документа: 10006 Результат: Владелец документа: Аристарх Павлов

# %%
def name_by_doc():
    user_input_number = input('Введите номер документа:')
    for person in documents:
        if user_input_number == person['number']:  
            return f'Результат: Владелец документа: {person["name"]}'
    return 'Документ не найден в базе'
print (name_by_doc())
# Out:
# Введите номер документа:10006
# Результат: Владелец документа: Аристарх Павлов

# %% [markdown]
# Пункт 2. Пользователь по команде "s" может по номеру документа узнать на какой полке он хранится Примеры работы:
#
# 1.
#
# Введите команду: s
#
# Введите номер документа: 10006 Результат: Документ хранится на полке: 2
#
# 2.
#
# Введите команду: p
#
# Введите номер документа: 12345 Результат: Документ не найден в базе

# %%
def shelf_by_doc():
    user_input_number = input('Введите номер документа:')
    for shelf, doc_list in directories.items():
          if user_input_number in doc_list:
            return f'Результат: Документ хранится на полке: {shelf}'
    return 'Документ не найден в базе'   
print(shelf_by_doc())
# Out:
# Введите номер документа:10006
# Результат: Документ хранится на полке: 2

# %% [markdown]
# Пункт 3. Пользователь по команде "l" может увидеть полную информацию по всем документам
# Пример работы:
#
# Введите команду: l Результат:
#
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1 №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1 №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2

# %%
def all_docs():
    for person in documents:
        def func1():   
            for shelf, doc_list in directories.items():
                if person['number'] in doc_list:
                    return  f'полка хранения: {shelf}'  
        print(f'№: {person["number"]} тип: {person["type"]} владелец:  {person["name"]} {func1()}')
print(all_docs())
# Out:
# №: 2207 876234 тип: passport владелец:  Василий Гупкин полка хранения: 1
# №: 11-2 тип: invoice владелец:  Геннадий Покемонов полка хранения: 1
# №: 10006 тип: insurance владелец:  Аристарх Павлов полка хранения: 2
# None

# %% [markdown]
# Пункт 4. Пользователь по команде "ads" может добавить новую полку Примеры работы:
#
# 1.
#
# Введите команду: ads
#
# Введите номер полки: 10 Результат: Полка добавлена. Текущий перечень полок: 1, 2, 3, 10.
#
# 2.
#
# Введите команду: ads
#
# Введите номер полки: 1 Результат: Такая полка уже существует. Текущий перечень полок: 1, 2, 3.

# %%
def add_new_shelf():
    new_shelf = input('Введите номер полки: ')

    if new_shelf in directories:
        return f'Результат: Такая полка уже существует. Текущий перечень полок: {list(directories.keys())}'
    else:
        directories[new_shelf] = []  
        return f'Результат: Полка добавлена. Текущий перечень полок: {list(directories.keys())}'
print(add_new_shelf())
# Out:
# Введите номер полки: 1
# Результат: Такая полка уже существует. Текущий перечень полок: ['1', '2', '3']

# %% [markdown]
# Пункт 5. Пользователь по команде "ds" может удалить существующую полку из данных (только если она пустая) Примеры работы:
#
# 1.
#
# Введите команду: ds
#
# Введите номер полки: 3 Результат: Полка удалена. Текущий перечень полок: 1, 2.
#
# 2.
#
# Введите команду: ds
#
# Введите номер полки: 1 Результат: На полке есть документа, удалите их перед удалением полки. Текущий перечень полок: 1, 2, 3.
#
# 3.
#
# Введите команду: ds
#
# Введите номер полки: 4 Результат: Такой полки не существует. Текущий перечень полок: 1, 2, 3.

# %%
def delete_shelf():
        shelf_number = input('Введите номер полки:')
        if shelf_number not in directories.keys():
            return f'Результат: Такой полки не существует. Текущий перечень полок: {list(directories.keys())}'
        else:
            if len(directories[shelf_number])==0:
                del(directories[shelf_number])
                return f'Полка удалена. Текущий перечень полок: {list(directories.keys())}'
            else: 
                return f' На полке есть документы, удалите их перед удалением полки.Текущий перечень полок: {list(directories.keys())}'
print(delete_shelf())
# Out:
# Введите номер полки:6
# Результат: Такой полки не существует. Текущий перечень полок: ['1', '2', '3']
